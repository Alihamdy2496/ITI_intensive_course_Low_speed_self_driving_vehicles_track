# %%
import cv2
print(cv2.__version__)
from matplotlib import pyplot as plt
import numpy as np
from math import sin, cos, tan, radians
# Out:
# 4.5.1

# %%
img = cv2.imread('./perspective02.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img);
rows,cols = img.shape[:2]
img.shape
# Out:
# (720, 1280, 3)

# %%
def nothing(x):
    pass
# create trackbars
while 1:
    pts1 = np.float32(
        [#610,  590   67    590
            [0, 350], [1279,  350],
            [0, 719], [1279, 719]
        ]
    )
    pts2 = np.float32(
        [
            [0,  0], [1279,  0],
            [550, 719], [739, 719]
        ]
    )
    M = cv2.getPerspectiveTransform(pts1 ,pts2)
    dst = cv2.warpPerspective(img, M, (cols,rows))
    for point in pts2:
        dst = cv2.circle(dst, (int(point[0]), int(point[1])), 1, (0, 0, 255), 2)
    out = dst
    for point in pts1:
        dst = cv2.circle(dst, (int(point[0]), int(point[1])), 1, (0, 255, 0), 2)
    out = dst
    cv2.imshow('Image', out)
    k = cv2.waitKey(1)
    if k == ord('q'):
        break
cv2.destroyAllWindows()

plt.imsave("out1.png",out);

# %%
img2 = cv2.imread('./perspective01.png')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2);
rows,cols = img2.shape[:2]
img2.shape
# Out:
# (540, 960, 3)

# %%
def nothing(x):
    pass
# create trackbars
while 1:
    pts1 = np.float32(
        [#0 250
            [150, 150], [809,  150],
            [0, 539], [959, 539]
        ]
    )
    pts2 = np.float32(
        [#200 539
            [0, 0], [959,  0],
            [400, 539], [509, 539]
        ]
    )
    M = cv2.getPerspectiveTransform(pts1 ,pts2)
    dst = cv2.warpPerspective(img2, M, (cols,rows))
    for point in pts2:
        dst = cv2.circle(dst, (int(point[0]), int(point[1])), 1, (0, 0, 255), 2)
    out = dst
    for point in pts1:
        dst = cv2.circle(dst, (int(point[0]), int(point[1])), 1, (0, 255, 0), 2)
    out = dst
    cv2.imshow('Image', out)
    k = cv2.waitKey(1)
    if k == ord('q'):
        break
cv2.destroyAllWindows()

plt.imsave("out2.png",out);
